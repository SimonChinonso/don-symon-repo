# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\user\\Documents\\world-data-2023.csv")

# %%
df
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# ...

# %%
pd.set_option('display.max.columns', None)

# %%
df.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   Density
# (P/Km2)                            195 non-null    object
#  2   Abbreviation                               188 non-null    object
#  3   Agricultural Land( %)                      188 non-null    object
#  4   Land Area(Km2)                             194 non-null    object
#  5   Armed Forces size                          171 non-null    object
#  6   Birth Rate                                 189 non-null    float64
#  7   Calling Code                               194 non-null    float64
#  8   Capital/Major City                         192 non-null    object
#  9   Co2-Emissions                              188 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Country                                       0
# Density\n(P/Km2)                              0
# Abbreviation                                  7
# Agricultural Land( %)                         7
# Land Area(Km2)                                1
# Armed Forces size                            24
# Birth Rate                                    6
# Calling Code                                  1
# Capital/Major City                            3
# Co2-Emissions                                 7
# CPI                                          17
# CPI Change (%)                               16
# Currency-Code                                15
# Fertility Rate                                7
# Forested Area (%)                             7
# Gasoline Price                               20
# GDP                                           2
# Gross primary education enrollment (%)        7
# Gross tertiary education enrollment (%)      12
# Infant mortality                              6
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
df['Armed Forces size'].unique()
# Out:
# array(['323,000', '9,000', '317,000', nan, '117,000', '0', '105,000',
#        '49,000', '58,000', '21,000', '82,000', '1,000', '19,000',
#        '221,000', '155,000', '32,000', '2,000', '12,000', '6,000',
#        '71,000', '11,000', '730,000', '8,000', '31,000', '27,000',
#        '191,000', '24,000', '72,000', '35,000', '122,000', '2,695,000',
#        '481,000', '10,000', '18,000', '76,000', '16,000', '23,000',
#        '134,000', '15,000', '13,000', '41,000', '836,000', '42,000',
#        '202,000', '138,000', '4,000', '25,000', '307,000', '7,000',
#        '26,000', '180,000', '146,000', '43,000', '3,000', '40,000',
#        '3,031,000', '676,000', '563,000', '209,000', '178,000', '347,000',
#        '261,000', '116,000', '29,000', '129,000', '80,000', '34,000',
#        '22,000', '136,000', '5,000', '336,000', '246,000', '513,000',
#        '112,000', '215,000', '1,469,000', '47,000', '936,000', '158,000',
# ...

# %%
data={',':'',
     '%':'',
     '$':'',
     'NaN':''}

# %%
df=df.replace(data,regex=True)

# %%
df.head(5)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                 58.10
# 1      Albania              105           AL                 43.10
# 2      Algeria               18           DZ                 17.40
# 3      Andorra              164           AD                 40.00
# 4       Angola               26           AO                 47.50
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0         652230            323000       32.49          93.0
# 1          28748              9000       11.78         355.0
# 2        2381741            317000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4        1246700            117000       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul          8672   149.9           2.30           AFN
# ...

# %%
data={'Armed Forces size':'Armed_Forces_size',
     'CPI Change (%)':'CPI_Change_(%)',
     'Gross tertiary education enrollment (%)':'Gross_tertiary_education_enrollment_(%)',
     'Life expectancy':'Life_expectancy',
     'Maternal mortality ratio':'Maternal_mortality_ratio',
     'Population: Labor force participation (%)':'Population_Labor_force_participation_(%)',
     'Tax revenue (%)':'Tax_revenue_(%)',
     'Total tax rate':'Total_tax_rate',
     'Unemployment rate':'Unemployment_rate',
     'Physicians per thousand':'Physicians_per_thousand',
     'Out of pocket health expenditure':'Out_of_pocket_health_expenditure',
     'Official language':'Official_language',
     'Minimum wage':'Minimum_wage',
     'Largest city':'Largest_city',
     'Infant mortality':'Infant_mortality',
     'Gross primary education enrollment (%)':'Gross_primary_education_enrollment_(%)',
     'Gasoline Price':'Gasoline_Price',
     'Agricultural Land( %)':'Agricultural_Land( %)',
     'Land Area(Km2)':'Land_Area(Km2)',
     'Birth Rate':'Birth_Rate',
     'Calling Code':'Calling_Code',
     'Capital/Major City':'Capital/Major_City',
     'Co2-Emissions':'Co2_Emissions',
     'Currency-Code':'Currency_Code',
     'Fertility Rate':'Fertility_Rate',
     'Forested Area (%)':'Forested_Area_(%)'}

# %%
df=df.rename(data,axis='columns')

# %%
df
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural_Land( %)  \
# 0    Afghanistan               60           AF                 58.10
# 1        Albania              105           AL                 43.10
# 2        Algeria               18           DZ                 17.40
# 3        Andorra              164           AD                 40.00
# 4         Angola               26           AO                 47.50
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                 24.50
# 191      Vietnam              314           VN                 39.30
# 192        Yemen               56           YE                 44.60
# 193       Zambia               25           ZM                 32.10
# 194     Zimbabwe               38           ZW                 41.90
#
#     Land_Area(Km2) Armed_Forces_size  Birth_Rate  Calling_Code  \
# 0           652230            323000       32.49          93.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Country                                   195 non-null    object
#  1   Density
# (P/Km2)                           195 non-null    object
#  2   Abbreviation                              188 non-null    object
#  3   Agricultural_Land( %)                     188 non-null    object
#  4   Land_Area(Km2)                            194 non-null    object
#  5   Armed_Forces_size                         171 non-null    object
#  6   Birth_Rate                                189 non-null    float64
#  7   Calling_Code                              194 non-null    float64
#  8   Capital/Major_City                        192 non-null    object
#  9   Co2_Emissions                             188 non-null    object
# ...

# %%
df['Gasoline_Price']=df['Gasoline_Price'].str.replace('$','')
df['GDP']=df['GDP'].str.replace('$','')
df['Minimum_wage']=df['Minimum_wage'].str.replace('$','')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17044\2439432327.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Gasoline_Price']=df['Gasoline_Price'].str.replace('$','')
# C:\Users\user\AppData\Local\Temp\ipykernel_17044\2439432327.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['GDP']=df['GDP'].str.replace('$','')
# C:\Users\user\AppData\Local\Temp\ipykernel_17044\2439432327.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Minimum_wage']=df['Minimum_wage'].str.replace('$','')

# %%
df
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural_Land( %)  \
# 0    Afghanistan               60           AF                 58.10
# 1        Albania              105           AL                 43.10
# 2        Algeria               18           DZ                 17.40
# 3        Andorra              164           AD                 40.00
# 4         Angola               26           AO                 47.50
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                 24.50
# 191      Vietnam              314           VN                 39.30
# 192        Yemen               56           YE                 44.60
# 193       Zambia               25           ZM                 32.10
# 194     Zimbabwe               38           ZW                 41.90
#
#     Land_Area(Km2) Armed_Forces_size  Birth_Rate  Calling_Code  \
# 0           652230            323000       32.49          93.0
# ...

# %%
df['Armed_Forces_size']=pd.to_numeric(df['Armed_Forces_size'])
df['CPI']=pd.to_numeric(df['CPI'])
df['CPI_Change_(%)']=pd.to_numeric(df['CPI_Change_(%)'])
df['Gross_tertiary_education_enrollment_(%)']=pd.to_numeric(df['Gross_tertiary_education_enrollment_(%)'])
df['Life_expectancy']=pd.to_numeric(df['Life_expectancy'])
df['Maternal_mortality_ratio']=pd.to_numeric(df['Maternal_mortality_ratio'])
df['Population_Labor_force_participation_(%)']=pd.to_numeric(df['Population_Labor_force_participation_(%)'])
df['Tax_revenue_(%)']=pd.to_numeric(df['Tax_revenue_(%)'])
df['Total_tax_rate']=pd.to_numeric(df['Total_tax_rate'])
df['Unemployment_rate']=pd.to_numeric(df['Unemployment_rate'])
df['Urban_population']=pd.to_numeric(df['Urban_population'])
df['Out_of_pocket_health_expenditure']=pd.to_numeric(df['Out_of_pocket_health_expenditure'])
df['Minimum_wage']=pd.to_numeric(df['Minimum_wage'])
df['Agricultural_Land( %)']=pd.to_numeric(df['Agricultural_Land( %)'])
df['Gasoline_Price']=pd.to_numeric(df['Gasoline_Price'])
df['GDP']=pd.to_numeric(df['GDP'])
df['Minimum_wage']=pd.to_numeric(df['Minimum_wage'])
df['Density\n(P/Km2)']=pd.to_numeric(df['Density\n(P/Km2)'])
df['Land_Area(Km2)']=pd.to_numeric(df['Land_Area(Km2)'])
df['Co2_Emissions']=pd.to_numeric(df['Co2_Emissions'])
df['Population']=pd.to_numeric(df['Population'])
df['Forested_Area_(%)']=pd.to_numeric(df['Forested_Area_(%)'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Country                                   195 non-null    object
#  1   Density
# (P/Km2)                           195 non-null    int64
#  2   Abbreviation                              188 non-null    object
#  3   Agricultural_Land( %)                     188 non-null    float64
#  4   Land_Area(Km2)                            194 non-null    float64
#  5   Armed_Forces_size                         171 non-null    float64
#  6   Birth_Rate                                189 non-null    float64
#  7   Calling_Code                              194 non-null    float64
#  8   Capital/Major_City                        192 non-null    object
#  9   Co2_Emissions                             188 non-null    float64
# ...

# %%
 df.describe()
# Out:
#        Density\n(P/Km2)  Agricultural_Land( %)  Land_Area(Km2)  \
# count        195.000000             188.000000    1.940000e+02
# mean         356.764103              39.117553    6.896244e+05
# std         1982.888967              21.783052    1.921609e+06
# min            2.000000               0.600000    0.000000e+00
# 25%           35.500000              21.700000    2.382825e+04
# 50%           89.000000              39.600000    1.195110e+05
# 75%          216.500000              55.375000    5.242560e+05
# max        26337.000000              82.600000    1.709824e+07
#
#        Armed_Forces_size  Birth_Rate  Calling_Code  Co2_Emissions  \
# count       1.710000e+02  189.000000    194.000000   1.880000e+02
# mean        1.592749e+05   20.214974    360.546392   1.777992e+05
# std         3.806288e+05    9.945774    323.236419   8.387903e+05
# min         0.000000e+00    5.900000      1.000000   1.100000e+01
# ...

# %%
df['Agricultural_Land( %)']=df['Agricultural_Land( %)'].fillna(39.18)
df['Land_Area(Km2)']=df['Land_Area(Km2)'].fillna(6.90)
df['Armed_Forces_size']=df['Armed_Forces_size'].fillna(1.59)
df['Birth_Rate']=df['Birth_Rate'].fillna(20.21)
df['Co2_Emissions']=df['Co2_Emissions'].fillna(1.78)
df['CPI']=df['CPI'].fillna(190.46)
df['CPI_Change_(%)']=df['CPI_Change_(%)'].fillna(6.72)
df['Fertility_Rate']=df['Fertility_Rate'].fillna(2.70)
df['Forested_Area_(%)']=df['Forested_Area_(%)'].fillna(32.02)
df['Gasoline_Price']=df['Gasoline_Price'].fillna(1.00)
df['GDP']=df['GDP'].fillna(4.78)
df['Gross_tertiary_education_enrollment_(%)']=df['Gross_tertiary_education_enrollment_(%)'].fillna(37.96)
df['Infant_mortality']=df['Infant_mortality'].fillna(21.33)
df['Life_expectancy']=df['Life_expectancy'].fillna(72.27)
df['Maternal_mortality_ratio']=df['Maternal_mortality_ratio'].fillna(160.39)
df['Minimum_wage']=df['Minimum_wage'].fillna(2.19)
df['Out_of_pocket_health_expenditure']=df['Out_of_pocket_health_expenditure'].fillna(32.63)
df['Physicians_per_thousand']=df['Physicians_per_thousand'].fillna(1.84)
df['Population']=df['Population'].fillna(3.94)
df['Population_Labor_force_participation_(%)']=df['Population_Labor_force_participation_(%)'].fillna(62.74)
df['Tax_revenue_(%)']=df['Tax_revenue_(%)'].fillna(16.57)
df['Total_tax_rate']=df['Total_tax_rate'].fillna(40.82)
df['Unemployment_rate']=df['Unemployment_rate'].fillna(6.89)
df['Urban_population']=df['Urban_population'].fillna(2.23)
df['Latitude']=df['Latitude'].fillna(19.09)
df['Longitude']=df['Longitude'].fillna(20.23)

# %%
df.head(5)
# Out:
#        Country  Density\n(P/Km2) Abbreviation  Agricultural_Land( %)  \
# 0  Afghanistan                60           AF                   58.1
# 1      Albania               105           AL                   43.1
# 2      Algeria                18           DZ                   17.4
# 3      Andorra               164           AD                   40.0
# 4       Angola                26           AO                   47.5
#
#    Land_Area(Km2)  Armed_Forces_size  Birth_Rate  Calling_Code  \
# 0        652230.0          323000.00       32.49          93.0
# 1         28748.0            9000.00       11.78         355.0
# 2       2381741.0          317000.00       24.28         213.0
# 3           468.0               1.59        7.20         376.0
# 4       1246700.0          117000.00       40.73         244.0
#
#   Capital/Major_City  Co2_Emissions     CPI  CPI_Change_(%) Currency_Code  \
# 0              Kabul         8672.0  149.90            2.30           AFN
# ...

# %%
df[['Country','Birth_Rate']].head(5)
# Out:
#        Country  Birth_Rate
# 0  Afghanistan       32.49
# 1      Albania       11.78
# 2      Algeria       24.28
# 3      Andorra        7.20
# 4       Angola       40.73

# %%
a=df.groupby('Country')['Birth_Rate'].sum().sort_values(ascending=False).head(5)

# %%
a
# Out:
# Country
# Niger                               46.08
# Chad                                42.17
# Somalia                             41.75
# Mali                                41.54
# Democratic Republic of the Congo    41.18
# Name: Birth_Rate, dtype: float64

# %%
b=df.groupby('Country')['Infant_mortality'].sum().sort_values(ascending=False).head(5)

# %%
b
# Out:
# Country
# Central African Republic    84.5
# Sierra Leone                78.5
# Somalia                     76.6
# Nigeria                     75.7
# Chad                        71.4
# Name: Infant_mortality, dtype: float64

# %%
import matplotlib as pyplot

# %%
a.plot(x='Country',y='Birth_Rate',kind='bar',title='Country Vs Birth_Rate')
# Out:
# <AxesSubplot:title={'center':'Country Vs Birth_Rate'}, xlabel='Country'>

# %%
b.plot(y='Infant_mortality',x=['Country'],kind='pie',title='Country Vs Infant_mortality',autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'Country Vs Infant_mortality'}, ylabel='Infant_mortality'>

# %%
c=df.groupby('Country')['Life_expectancy'].sum().sort_values(ascending=False).head(5)

# %%
c.plot(y='Life_expectancy',x='Country',kind='barh',title='Country Vs Life_expectancy')
# Out:
# <AxesSubplot:title={'center':'Country Vs Life_expectancy'}, ylabel='Country'>

# %%
d=df.groupby('Country')['Life_expectancy'].sum().sort_values(ascending=True).head(5)

# %%
d
# Out:
# Country
# Central African Republic    52.8
# Lesotho                     53.7
# Chad                        54.0
# Nigeria                     54.3
# Sierra Leone                54.3
# Name: Life_expectancy, dtype: float64

# %%
e=df.groupby('Country')['Unemployment_rate'].sum().sort_values(ascending=False).head(5)

# %%
e.plot(y='Unemployment_rate',x='Country',kind='pie',title='Country Vs Unemployment_rate',autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'Country Vs Unemployment_rate'}, ylabel='Unemployment_rate'>

# %%
f=df[['Country','Maternal_mortality_ratio','Infant_mortality']].head(5)

# %%
f.plot(y=['Maternal_mortality_ratio','Infant_mortality'],x='Country',kind='bar',title='Country Vs Maternal_mortality_ratio & Infant_mortality')
# Out:
# <AxesSubplot:title={'center':'Country Vs Maternal_mortality_ratio & Infant_mortality'}, xlabel='Country'>

# %%
g=df.groupby('Country')['Co2_Emissions'].sum().sort_values(ascending=False).head(5)

# %%
g.plot(y='Co2_Emissions',x='Country',kind='pie',title='Country Vs Co2_Emissions',autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'Country Vs Co2_Emissions'}, ylabel='Co2_Emissions'>

# %%
h=df.groupby('Country')['Population'].sum().sort_values(ascending=False).head(10)

# %%
h
# Out:
# Country
# China            1.397715e+09
# India            1.366418e+09
# United States    3.282395e+08
# Indonesia        2.702039e+08
# Pakistan         2.165653e+08
# Brazil           2.125594e+08
# Nigeria          2.009636e+08
# Bangladesh       1.673108e+08
# Russia           1.443735e+08
# Japan            1.262266e+08
# Name: Population, dtype: float64

# %%
k=df.groupby('Country')['Armed_Forces_size'].sum().sort_values(ascending=False).head(5)

# %%
k
# Out:
# Country
# India            3031000.0
# China            2695000.0
# North Korea      1469000.0
# Russia           1454000.0
# United States    1359000.0
# Name: Armed_Forces_size, dtype: float64

# %%
k.plot(y='Armed_Forces_size',x='Country',kind='barh',title='Country Vs Armed_Forces_size')
# Out:
# <AxesSubplot:title={'center':'Country Vs Armed_Forces_size'}, ylabel='Country'>

# %%
k.plot(y='Armed_Forces_size',x='Country',title='Country Vs Armed_Forces_size',color='red',grid=True)
# Out:
# <AxesSubplot:title={'center':'Country Vs Armed_Forces_size'}, xlabel='Country'>

# %%
j=df[['Country','Birth_Rate']].head(5)

# %%
j
# Out:
#        Country  Birth_Rate
# 0  Afghanistan       32.49
# 1      Albania       11.78
# 2      Algeria       24.28
# 3      Andorra        7.20
# 4       Angola       40.73

# %%
j.plot(y='Country',x='Birth_Rate',kind='scatter',title='Country Vs Birth_Rate',grid=True)
# Out:
# <AxesSubplot:title={'center':'Country Vs Birth_Rate'}, xlabel='Birth_Rate', ylabel='Country'>

# %%
g=df.groupby('Country')['Agricultural_Land( %)'].sum().sort_values(ascending=False).head(5)

# %%
g.plot(y='Agricultural_Land( %)',x='Country',title='Country Vs Agricultural_Land( %)',color='blue',grid=True)
# Out:
# <AxesSubplot:title={'center':'Country Vs Agricultural_Land( %)'}, xlabel='Country'>

# %%
h=df.groupby('Country')['GDP'].sum().sort_values(ascending=False).head(5)

# %%
h.plot(y='GDP',x='Country',grid=True,color='yellow',title='Country Vs GDP')
# Out:
# <AxesSubplot:title={'center':'Country Vs GDP'}, xlabel='Country'>

# %%
df_wage=df.groupby('Country')['Minimum_wage'].sum().sort_values(ascending=True).head(5)

# %%
df_wage
# Out:
# Country
# Venezuela     0.01
# Uganda        0.01
# Cuba          0.05
# Georgia       0.05
# Kyrgyzstan    0.09
# Name: Minimum_wage, dtype: float64

# %%
df_wage2=df.groupby('Country')['Minimum_wage'].sum().sort_values(ascending=False).head(5)

# %%
df_wage2
# Out:
# Country
# Australia      13.59
# Luxembourg     13.05
# Monaco         11.72
# New Zealand    11.49
# France         11.16
# Name: Minimum_wage, dtype: float64

# %%
df_wage2.plot(y='Minimum_wage',x='Country',grid=True,color='green',title='Country Vs Minimum_wage')
# Out:
# <AxesSubplot:title={'center':'Country Vs Minimum_wage'}, xlabel='Country'>

# %%
df_health=df.groupby('Country')['Out_of_pocket_health_expenditure'].sum().sort_values(ascending=False).head(5)

# %%
df_health
# Out:
# Country
# Armenia        81.6
# Yemen          81.0
# Azerbaijan     78.6
# Afghanistan    78.4
# Iraq           76.5
# Name: Out_of_pocket_health_expenditure, dtype: float64

# %%
df_health.plot(y='Out_of_pocket_health_expenditure',x='Country',grid=True,title='Country Vs Out_of_pocket_health_expenditure')
# Out:
# <AxesSubplot:title={'center':'Country Vs Out_of_pocket_health_expenditure'}, xlabel='Country'>

# %%
t=df['Birth_Rate'].head(15)

# %%
t
# Out:
# 0     32.49
# 1     11.78
# 2     24.28
# 3      7.20
# 4     40.73
# 5     15.33
# 6     17.02
# 7     13.99
# 8     12.60
# 9      9.70
# 10    14.00
# 11    13.97
# 12    13.99
# 13    18.18
# 14    10.65
# Name: Birth_Rate, dtype: float64

# %%
dft=pd.Series(t)

# %%
dft
# Out:
# 0     32.49
# 1     11.78
# 2     24.28
# 3      7.20
# 4     40.73
# 5     15.33
# 6     17.02
# 7     13.99
# 8     12.60
# 9      9.70
# 10    14.00
# 11    13.97
# 12    13.99
# 13    18.18
# 14    10.65
# Name: Birth_Rate, dtype: float64

# %%
dft.max()
# Out:
# 40.73

# %%
dft.min()
# Out:
# 7.2

# %%
dft.mean()
# Out:
# 17.06066666666667

# %%
dft.describe()
# Out:
# count    15.000000
# mean     17.060667
# std       8.994998
# min       7.200000
# 25%      12.190000
# 50%      13.990000
# 75%      17.600000
# max      40.730000
# Name: Birth_Rate, dtype: float64

# %% [markdown]
# # ADVANCED VISUALIZATION USING SEABORN PACKAGE

# %%
#Visualization can be helpful to easily understand complex patterns abd
#concepts using seaborn package
#It represents the insights in pictorial formats.
#Seaborn is an open-source library for high level interactive and attractive
#statistical visualiation
#Seaborn uses matplotlib as a base library and, offers more simple,easy-to-understand
#interactive and attractive visualizations.
#You can install seaborn library in the following way:
#!pip install seaborn
